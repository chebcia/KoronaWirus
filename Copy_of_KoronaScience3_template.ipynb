# %% [markdown]
# <a href="https://colab.research.google.com/github/chebcia/KoronaWirus/blob/master/Copy_of_KoronaScience3_template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *Tamplate do zadań w dniu 3 kursu KoronaScience*

# %%
def rectangle_area(a,b):
  if a<0 or b<0:
    raise ValueError("if the number wasd negative")

# %%
import pandas as pd
from datetime import datetime
import numpy as np


wczoraj = datetime.today().day-1
miesiac = datetime.today().month


def check(dzien, mies):
	url = f"https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Confirmed.csv"
	df = pd.read_csv(url, error_bad_lines=False)
	result = df.loc[df["Country/Region"]=="Poland"][f"{mies}/{dzien}/20"]
	print(result)
   #return coś

print(f"data: {wczoraj}/{miesiac}")
print("przypadki: ", check(wczoraj, miesiac))
# Out:
# data: 15/3
# 74    119
# Name: 3/15/20, dtype: int64
# przypadki:  None

# %%
df.sort_values(by=["col1", "col2"])
# Out:
#   col1  col2  col3
# 1    A   1.0     1
# 0    A   2.0     0
# 2    B   9.0     9
# 5    C   4.0     3
# 4    D   NaN     2
# 3  NaN   8.0     4

# %%
df.sort_values(by=["col1", "col2"], ascending = False, na_position="first")
# Out:
#   col1  col2  col3
# 3  NaN   8.0     4
# 4    D   NaN     2
# 5    C   4.0     3
# 2    B   9.0     9
# 0    A   2.0     0
# 1    A   1.0     1

# %%
df["col2"].fillna(4, inplace=True)

# %%
df["col2"].fillna(df["col2"].mean(), inplace=True)

# %%
df.loc[df.col1== "A"]
# Out:
#   col1  col2  col3
# 0    A   2.0     0
# 1    A   1.0     1
# 2    B   9.0     9
# 3  NaN   8.0     4
# 4    D   4.0     2
# 5    C   4.0     3

# %%
df.loc[(df.index>1) & (df.index<4)]
# Out:
#   col1  col2  col3
# 2    B   9.0     9
# 3  NaN   8.0     4

# %%
df.iloc[2:4,:]
# Out:
#   col1  col2  col3
# 2    B   9.0     9
# 3  NaN   8.0     4

# %%
df.groupby("col1").sum()
# Out:
#       col2  col3
# col1
# A      3.0     1
# B      9.0     9
# C      4.0     3
# D      4.0     2

# %%
df.rename(columns={"col1": "kolumna1"})
# Out:
#   kolumna1  col2  col3
# 0        A   2.0     0
# 1        A   1.0     1
# 2        B   9.0     9
# 3      NaN   8.0     4
# 4        D   4.0     2
# 5        C   4.0     3

# %%
check(wczoraj,miesiac)
# Out:
# 74    119
# Name: 3/15/20, dtype: int64

# %% [markdown]
# *Szybki kurs operacji na DataFrame (pandas)*

# %%
df = pd.DataFrame({
    'col1': ['A', 'A', 'B', np.nan, 'D', 'C'],
    'col2': [2, 1, 9, 8, np.nan, 4],
    'col3': [0, 1, 9, 4, 2, 3],
})
df
# Out:
#   col1  col2  col3
# 0    A   2.0     0
# 1    A   1.0     1
# 2    B   9.0     9
# 3  NaN   8.0     4
# 4    D   NaN     2
# 5    C   4.0     3

# %% [markdown]
# *Przykładowe operacje na danych o koronawirusie*

# %%
url = f"https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Confirmed.csv"
df = pd.read_csv(url, error_bad_lines=False)

# %%
def top(data):
  return df[["Province/State", "Country/Region", data] ].sort_values(by=data).tail(10)

# %%
df.loc[df["Country/Region"] =="China" ,:].sort_values(by=data14).tail(10).style.background_gradient(cmap="RdBu_r")
# Out:
# <style  type="text/css" >
#     #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col2 {
#             background-color:  #f8f2ef;
#             color:  #000000;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col3 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col4 {
#             background-color:  #073467;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col5 {
#             background-color:  #073467;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col6 {
#             background-color:  #0e4179;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col7 {
#             background-color:  #134c87;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col8 {
#             background-color:  #10457e;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col9 {
#             background-color:  #114781;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col10 {
#             background-color:  #09386d;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col11 {
#             background-color:  #08366a;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col12 {
#             background-color:  #073467;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col13 {
#             background-color:  #063264;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col14 {
#             background-color:  #063264;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col15 {
#             background-color:  #063264;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col16 {
#             background-color:  #063264;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col17 {
#             background-color:  #063264;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col18 {
#             background-color:  #063264;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col19 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col20 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col21 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col22 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col23 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col24 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col25 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col26 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col27 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col28 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col29 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col30 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col31 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col32 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col33 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col34 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col35 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col36 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col37 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col38 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col39 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col40 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col41 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col42 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col43 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col44 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col45 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col46 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col47 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col48 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col49 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col50 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col51 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col52 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col53 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col54 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col55 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col56 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row0_col57 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row1_col2 {
#             background-color:  #e8896c;
#             color:  #000000;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row1_col3 {
#             background-color:  #8d0c25;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row1_col4 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_299b7a76_679c_11ea_b63c_0242ac1c0002row1_col5 {
#             background-c

# %%
def brakwirusa(data):
  return df.loc[df[data]==0].count()[1]

# %%
brakwirusa(data14)
# Out:
# 194

# %%
data14 = "3/15/20"

# %%
top(data14)
# Out:
#     Province/State Country/Region  3/15/20
# 160          Henan          China     1273
# 159      Guangdong          China     1360
# 31             NaN    Switzerland     2200
# 158         France         France     4499
# 11             NaN        Germany     5795
# 18             NaN          Spain     7798
# 157            NaN   Korea, South     8162
# 156            NaN           Iran    13938
# 16             NaN          Italy    24747
# 155          Hubei          China    67794

# %% [markdown]
# *Mapa przypadków na świecie*

# %%
import plotly.express as px

# %%
formated_gdf = df.groupby(["Country/Region"]).max()

# %%
formated_gdf
# Out:
#                                Province/State      Lat  ...  3/14/20  3/15/20
# Country/Region                                          ...
# Afghanistan                               NaN  33.0000  ...       11       16
# Albania                                   NaN  41.1533  ...       38       42
# Algeria                                   NaN  28.0339  ...       37       48
# Andorra                                   NaN  42.5063  ...        1        1
# Antigua and Barbuda                       NaN  17.0608  ...        1        1
# ...                                       ...      ...  ...      ...      ...
# Uruguay                                   NaN -32.5228  ...        4        4
# Uzbekistan                                NaN  41.3775  ...        0        1
# Venezuela                                 NaN   6.4238  ...        2       10
# Vietnam                                   NaN  16.0000  ...       53       56
# occupied Palestinian territory            NaN  31.9522  ...        0        0
#
# [147 rows x 57 columns]

# %%
formated_gdf = formated_gdf.reset_index()

# %%
formated_gdf['size'] = formated_gdf[data14].pow(0,3)

# %%
formated_gdf = df.groupby

# %%
formated_gdf
# Out:
# <bound method NDFrame.groupby of     Province/State            Country/Region  ...  3/14/20  3/15/20
# 0              NaN                  Thailand  ...       82      114
# 1              NaN                     Japan  ...      773      839
# 2              NaN                 Singapore  ...      212      226
# 3              NaN                     Nepal  ...        1        1
# 4              NaN                  Malaysia  ...      238      428
# ..             ...                       ...  ...      ...      ...
# 445            NaN  Central African Republic  ...        0        1
# 446            NaN       Congo (Brazzaville)  ...        0        1
# 447            NaN         Equatorial Guinea  ...        0        1
# 448        Mayotte                    France  ...        0        1
# 449            NaN                Uzbekistan  ...        0        1
#
# [450 rows x 58 columns]>

# %%
fig = px.scatter_geo(formated_gdf, locations="Country/Region", locationmode='country names', 
                     color="3/14/20", size='3/14/20', hover_name="Country/Region", 
                     range_color= [0, max(formated_gdf['3/14/20'])+2], 
                     projection="natural earth"  
                     )

fig.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-f11e4b37258b> in <module>()
#       1 fig = px.scatter_geo(formated_gdf, locations="Country/Region", locationmode='country names',
#       2                      color="3/14/20", size='3/14/20', hover_name="Country/Region",
# ----> 3                      range_color= [0, max(formated_gdf['3/14/20'])+2],
#       4                      projection="natural earth"
#       5                      )
#
# TypeError: 'method' object is not subscriptable
